# %%
import pandas as pd
df = pd.read_csv("/home/ubuntu/Machine-Learning-Algorithms/titanic_test.csv")
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.head(11)
# Out:
#     PassengerId  Pclass                                          Name     Sex  \
# 0           892       3                              Kelly, Mr. James    male
# 1           893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2           894       2                     Myles, Mr. Thomas Francis    male
# 3           895       3                              Wirz, Mr. Albert    male
# 4           896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5           897       3                    Svensson, Mr. Johan Cervin    male
# 6           898       3                          Connolly, Miss. Kate  female
# 7           899       2                  Caldwell, Mr. Albert Francis    male
# 8           900       3     Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female
# 9           901       3                       Davies, Mr. John Samuel    male
# 10          902       3                              Ilieff, Mr. Ylio    male
#
# ...

# %%
df.head(12)
# Out:
#     PassengerId  Pclass                                          Name     Sex  \
# 0           892       3                              Kelly, Mr. James    male
# 1           893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2           894       2                     Myles, Mr. Thomas Francis    male
# 3           895       3                              Wirz, Mr. Albert    male
# 4           896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5           897       3                    Svensson, Mr. Johan Cervin    male
# 6           898       3                          Connolly, Miss. Kate  female
# 7           899       2                  Caldwell, Mr. Albert Francis    male
# 8           900       3     Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female
# 9           901       3                       Davies, Mr. John Samuel    male
# 10          902       3                              Ilieff, Mr. Ylio    male
# ...

# %%
df.tail(8)
# Out:
#      PassengerId  Pclass                                             Name  \
# 410         1302       3                           Naughton, Miss. Hannah
# 411         1303       1  Minahan, Mrs. William Edward (Lillian E Thorpe)
# 412         1304       3                   Henriksson, Miss. Jenny Lovisa
# 413         1305       3                               Spector, Mr. Woolf
# 414         1306       1                     Oliva y Ocana, Dona. Fermina
# 415         1307       3                     Saether, Mr. Simon Sivertsen
# 416         1308       3                              Ware, Mr. Frederick
# 417         1309       3                         Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 410  female   NaN      0      0              365237    7.7500   NaN        Q
# 411  female  37.0      1      0               19928   90.0000   C78        Q
# ...

# %%
df.shape
# Out:
# (418, 11)

# %%
[rows,cols] = df.shape

# %%
rows
# Out:
# 418

# %%
cols
# Out:
# 11

# %%
[a,b] = df.shape

# %%
a
# Out:
# 418

# %%
b
# Out:
# 11

# %%
df[2:6]
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5          897       3                    Svensson, Mr. Johan Cervin    male
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S
# 5  14.0      0      0     7538   9.2250   NaN        S

# %%
df.columns
# Out:
# Index(['PassengerId', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch',
#        'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.Cabin
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 413     NaN
# 414    C105
# 415     NaN
# 416     NaN
# 417     NaN
# Name: Cabin, Length: 418, dtype: object

# %%
df.Cabin.head(5)
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: Cabin, dtype: object

# %%
df.Age.head()
# Out:
# 0    34.5
# 1    47.0
# 2    62.0
# 3    27.0
# 4    22.0
# Name: Age, dtype: float64

# %%
df["Ticket"].head()
# Out:
# 0     330911
# 1     363272
# 2     240276
# 3     315154
# 4    3101298
# Name: Ticket, dtype: object

# %%
type(df["Age"])
# Out:
# pandas.core.series.Series

# %%
df[["Name","Age","Ticket"]].tail(5)
# Out:
#                              Name   Age              Ticket
# 413            Spector, Mr. Woolf   NaN           A.5. 3236
# 414  Oliva y Ocana, Dona. Fermina  39.0            PC 17758
# 415  Saether, Mr. Simon Sivertsen  38.5  SOTON/O.Q. 3101262
# 416           Ware, Mr. Frederick   NaN              359309
# 417      Peter, Master. Michael J   NaN                2668

# %%
df[:]
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df["Age"].mean()
# Out:
# 30.272590361445783

# %%
df["Age"].std()
# Out:
# 14.18120923562442

# %%
df.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
df[["Name","Ticket"]][df["Age"]==df["Age"].max()]
# Out:
#                                                  Name Ticket
# 96  Cavendish, Mrs. Tyrell William (Julia Florence...  19877

# %%
df[:]
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df.set_index("PassengerId",inplace=True)

# %%
df
# Out:
#              Pclass                                          Name     Sex  \
# PassengerId
# 892               3                              Kelly, Mr. James    male
# 893               3              Wilkes, Mrs. James (Ellen Needs)  female
# 894               2                     Myles, Mr. Thomas Francis    male
# 895               3                              Wirz, Mr. Albert    male
# 896               3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ...             ...                                           ...     ...
# 1305              3                            Spector, Mr. Woolf    male
# 1306              1                  Oliva y Ocana, Dona. Fermina  female
# 1307              3                  Saether, Mr. Simon Sivertsen    male
# 1308              3                           Ware, Mr. Frederick    male
# 1309              3                      Peter, Master. Michael J    male
#
# ...

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df.set_index("Pclass",inplace=True)

# %%
df
# Out:
#         PassengerId                                          Name     Sex  \
# Pclass
# 3               892                              Kelly, Mr. James    male
# 3               893              Wilkes, Mrs. James (Ellen Needs)  female
# 2               894                     Myles, Mr. Thomas Francis    male
# 3               895                              Wirz, Mr. Albert    male
# 3               896  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ...             ...                                           ...     ...
# 3              1305                            Spector, Mr. Woolf    male
# 1              1306                  Oliva y Ocana, Dona. Fermina  female
# 3              1307                  Saether, Mr. Simon Sivertsen    male
# 3              1308                           Ware, Mr. Frederick    male
# 3              1309                      Peter, Master. Michael J    male
#
#          Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#      Pclass  PassengerId                                          Name  \
# 0         3          892                              Kelly, Mr. James
# 1         3          893              Wilkes, Mrs. James (Ellen Needs)
# 2         2          894                     Myles, Mr. Thomas Francis
# 3         3          895                              Wirz, Mr. Albert
# 4         3          896  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..      ...          ...                                           ...
# 413       3         1305                            Spector, Mr. Woolf
# 414       1         1306                  Oliva y Ocana, Dona. Fermina
# 415       3         1307                  Saether, Mr. Simon Sivertsen
# 416       3         1308                           Ware, Mr. Frederick
# 417       3         1309                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df
# Out:
#      Pclass  PassengerId                                          Name  \
# 0         3          892                              Kelly, Mr. James
# 1         3          893              Wilkes, Mrs. James (Ellen Needs)
# 2         2          894                     Myles, Mr. Thomas Francis
# 3         3          895                              Wirz, Mr. Albert
# 4         3          896  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..      ...          ...                                           ...
# 413       3         1305                            Spector, Mr. Woolf
# 414       1         1306                  Oliva y Ocana, Dona. Fermina
# 415       3         1307                  Saether, Mr. Simon Sivertsen
# 416       3         1308                           Ware, Mr. Frederick
# 417       3         1309                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df.set_index("PassengerId",inplace=True)

# %%
df
# Out:
#              Pclass                                          Name     Sex  \
# PassengerId
# 892               3                              Kelly, Mr. James    male
# 893               3              Wilkes, Mrs. James (Ellen Needs)  female
# 894               2                     Myles, Mr. Thomas Francis    male
# 895               3                              Wirz, Mr. Albert    male
# 896               3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ...             ...                                           ...     ...
# 1305              3                            Spector, Mr. Woolf    male
# 1306              1                  Oliva y Ocana, Dona. Fermina  female
# 1307              3                  Saether, Mr. Simon Sivertsen    male
# 1308              3                           Ware, Mr. Frederick    male
# 1309              3                      Peter, Master. Michael J    male
#
# ...

# %%
df.loc[895]
# Out:
# Pclass                     3
# Name        Wirz, Mr. Albert
# Sex                     male
# Age                       27
# SibSp                      0
# Parch                      0
# Ticket                315154
# Fare                  8.6625
# Cabin                    NaN
# Embarked                   S
# Name: 895, dtype: object

# %%
df.reset_index(inplace=True)

# %%
df.set_index("Sex",inplace=True)

# %%
df.loc["female"]
# Out:
#         PassengerId  Pclass                                             Name  \
# Sex
# female          893       3                 Wilkes, Mrs. James (Ellen Needs)
# female          896       3     Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# female          898       3                             Connolly, Miss. Kate
# female          900       3        Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# female          904       1    Snyder, Mrs. John Pillsbury (Nelle Stevenson)
# ...             ...     ...                                              ...
# female         1301       3                        Peacock, Miss. Treasteall
# female         1302       3                           Naughton, Miss. Hannah
# female         1303       1  Minahan, Mrs. William Edward (Lillian E Thorpe)
# female         1304       3                   Henriksson, Miss. Jenny Lovisa
# female         1306       1                     Oliva y Ocana, Dona. Fermina
#
# ...

# %%
df = pd.DataFrame({"Name":["Tanvi","Komal","Ankita","Ashwini"],"Location":["Kasarwadi","Kej","Ganesh Nagar","Nigdi"]})
df
# Out:
#       Name      Location
# 0    Tanvi     Kasarwadi
# 1    Komal           Kej
# 2   Ankita  Ganesh Nagar
# 3  Ashwini         Nigdi

# %%
df = pd.DataFrame([("tanvi","kasarwadi",87.00),("komal","kej",79),("ankita","ganesh khind",88.3),("ashwini","nighdi",89.00)],columns=["name","loction","marks"])
df
# Out:
#       name       loction  marks
# 0    tanvi     kasarwadi   87.0
# 1    komal           kej   79.0
# 2   ankita  ganesh khind   88.3
# 3  ashwini        nighdi   89.0

# %%
df = pd.DataFrame([{"name":"tanvi","location":"kasarwadi"},
                   {"name":"komal","location":"kej"},
                   {"name":"ankita","location":"ganesh nagar"}])
df
# Out:
#      name      location
# 0   tanvi     kasarwadi
# 1   komal           kej
# 2  ankita  ganesh nagar

# %%
print("Multiples ways of reading and writing to csv files.")
# Out:
# Multiples ways of reading and writing to csv files.

# %%
df = pd.read_csv("/home/ubuntu/Machine-Learning-Algorithms/titanic_test.csv")
df.head(5)
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df = pd.read_csv("/home/ubuntu/Machine-Learning-Algorithms/titanic_test.csv",skiprows=1)
print("The first row is skipped which consisted of the real headers, thus the first row of data has taken the place of the header")
df
# Out:
# The first row is skipped which consisted of the real headers, thus the first row of data has taken the place of the header
#       892  3                              Kelly, Mr. James    male  34.5  0  \
# 0     893  3              Wilkes, Mrs. James (Ellen Needs)  female  47.0  1
# 1     894  2                     Myles, Mr. Thomas Francis    male  62.0  0
# 2     895  3                              Wirz, Mr. Albert    male  27.0  0
# 3     896  3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0  1
# 4     897  3                    Svensson, Mr. Johan Cervin    male  14.0  0
# ..    ... ..                                           ...     ...   ... ..
# 412  1305  3                            Spector, Mr. Woolf    male   NaN  0
# 413  1306  1                  Oliva y Ocana, Dona. Fermina  female  39.0  0
# 414  1307  3                  Saether, Mr. Simon Sivertsen    male  38.5  0
# 415  1308  3                           Ware, Mr. Frederick    male   NaN  0
# ...

# %%
df = pd.read_csv("/home/ubuntu/Machine-Learning-Algorithms/titanic_test.csv",header=None)
print("By default first row appears as the header but when we set header=None, the first row which in this case consists of header is here considered as data and appears in data section")
df
# Out:
# By default first row appears as the header but when we set header=None, the first row which in this case consists of header is here considered as data and appears in data section
#               0       1                                 2       3     4   \
# 0    PassengerId  Pclass                              Name     Sex   Age
# 1            892       3                  Kelly, Mr. James    male  34.5
# 2            893       3  Wilkes, Mrs. James (Ellen Needs)  female    47
# 3            894       2         Myles, Mr. Thomas Francis    male    62
# 4            895       3                  Wirz, Mr. Albert    male    27
# ..           ...     ...                               ...     ...   ...
# 414         1305       3                Spector, Mr. Woolf    male   NaN
# 415         1306       1      Oliva y Ocana, Dona. Fermina  female    39
# 416         1307       3      Saether, Mr. Simon Sivertsen    male  38.5
# ...

# %%
df = pd.read_csv("/home/ubuntu/Machine-Learning-Algorithms/titanic_test.csv",header=None,names=[])
print("To set new values to the column header we use names parameter, in which the column names are supplied in the form of list")
df
# Out:
# To set new values to the column header we use names parameter, in which the column names are supplied in the form of list
# Empty DataFrame
# Columns: []
# ...

# %%
df = pd.read_csv("/home/ubuntu/Machine-Learning-Algorithms/titanic_test.csv",header=None,names=["v1","v2","v3","v4","v5","v6","v7","v8","v9","v10","v11"])
df
# Out:
#               v1      v2                                v3      v4    v5  \
# 0    PassengerId  Pclass                              Name     Sex   Age
# 1            892       3                  Kelly, Mr. James    male  34.5
# 2            893       3  Wilkes, Mrs. James (Ellen Needs)  female    47
# 3            894       2         Myles, Mr. Thomas Francis    male    62
# 4            895       3                  Wirz, Mr. Albert    male    27
# ..           ...     ...                               ...     ...   ...
# 414         1305       3                Spector, Mr. Woolf    male   NaN
# 415         1306       1      Oliva y Ocana, Dona. Fermina  female    39
# 416         1307       3      Saether, Mr. Simon Sivertsen    male  38.5
# 417         1308       3               Ware, Mr. Frederick    male   NaN
# 418         1309       3          Peter, Master. Michael J    male   NaN
#
#         v6     v7                  v8       v9    v10       v11
# ...

# %%
df = pd.read_csv("/home/ubuntu/Machine-Learning-Algorithms/titanic_test.csv",skiprows=1,header=None,names=["v1","v2","v3","v4","v5","v6","v7","v8","v9","v10","v11"])
print("skiprows=1 parameter skips the first row that consists of the headers for the columns.")
df
# Out:
# skiprows=1 parameter skips the first row that consists of the headers for the columns.
#        v1  v2                                            v3      v4    v5  v6  \
# 0     892   3                              Kelly, Mr. James    male  34.5   0
# 1     893   3              Wilkes, Mrs. James (Ellen Needs)  female  47.0   1
# 2     894   2                     Myles, Mr. Thomas Francis    male  62.0   0
# 3     895   3                              Wirz, Mr. Albert    male  27.0   0
# 4     896   3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0   1
# ..    ...  ..                                           ...     ...   ...  ..
# 413  1305   3                            Spector, Mr. Woolf    male   NaN   0
# 414  1306   1                  Oliva y Ocana, Dona. Fermina  female  39.0   0
# 415  1307   3                  Saether, Mr. Simon Sivertsen    male  38.5   0
# 416  1308   3                           Ware, Mr. Frederick    male   NaN   0
# ...

# %%
df = pd.read_csv("/home/ubuntu/Machine-Learning-Algorithms/titanic_test.csv",na_values=[0,"Q"])
print("navalues parameter is used to replace some values(values that represent absence of data) with NaN value")
df
# Out:
# navalues parameter is used to replace some values(values that represent absence of data) with NaN value
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
# ...

# %%
df.to_csv("csv_file.csv",index=False,columns=["PassengerId","Name","Ticket"],header=False)

# %%
df.head(7)
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5          897       3                    Svensson, Mr. Johan Cervin    male
# 6          898       3                          Connolly, Miss. Kate  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5    NaN    NaN   330911   7.8292   NaN      NaN
# 1  47.0    1.0    NaN   363272   7.0000   NaN        S
# 2  62.0    NaN    NaN   240276   9.6875   NaN      NaN
# 3  27.0    NaN    NaN   315154   8.6625   NaN        S
# 4  22.0    1.0    1.0  3101298  12.2875   NaN        S
# ...

# %%
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df = pd.read_csv("/home/ubuntu/Machine-Learning-Algorithms/titanic_test.csv",nrows=10)
df
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 5          897       3                    Svensson, Mr. Johan Cervin    male
# 6          898       3                          Connolly, Miss. Kate  female
# 7          899       2                  Caldwell, Mr. Albert Francis    male
# 8          900       3     Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female
# 9          901       3                       Davies, Mr. John Samuel    male
#
#     Age  SibSp  Parch     Ticket     Fare  Cabin Embarked
# 0  34.5      0      0     330911   7.8292    NaN        Q
# ...

# %%
df.to_excel("new.xlsx")

# %%
def convertSex(cell):
    if pd.isnull(cell):
        return 0
    return cell

df = pd.read_excel("new.xlsx",converters = {
    "Cabin": convertSex
})
df
# Out:
#    Unnamed: 0  PassengerId  Pclass  \
# 0           0          892       3
# 1           1          893       3
# 2           2          894       2
# 3           3          895       3
# 4           4          896       3
# 5           5          897       3
# 6           6          898       3
# 7           7          899       2
# 8           8          900       3
# 9           9          901       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                    Svensson, Mr. Johan Cervin    male  14.0      0      0
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  PassengerId  Pclass  \
# 0           0          892       3
# 1           1          893       3
# 2           2          894       2
# 3           3          895       3
# 4           4          896       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.fillna()
# Out:
#    Unnamed: 0  PassengerId  Pclass  \
# 0           0          892       3
# 1           1          893       3
# 2           2          894       2
# 3           3          895       3
# 4           4          896       3
# 5           5          897       3
# 6           6          898       3
# 7           7          899       2
# 8           8          900       3
# 9           9          901       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                    Svensson, Mr. Johan Cervin    male  14.0      0      0
# ...
